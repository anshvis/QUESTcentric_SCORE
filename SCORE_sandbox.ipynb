# %%
# -*- coding: utf-8 -*-
"""
Spyder Editor

This is a temporary script file.
"""

import pandas as pd
import matplotlib.pyplot as plt

SCORE = pd.read_csv("score_data_cleaned.csv")
df = pd.DataFrame(SCORE)

# important vectors
broadcast_Date = df.iloc[:, 1]
broadcast_Time = df.iloc[:, 2]
region = df.iloc[:, 10]
audience = df.iloc[:, 14]
PV = df.iloc[:, 15]
keywords = df.iloc[:, 27]
media_Type = df.iloc[:, 30]

# %%
#%%

# What content generates the greatest publicity value in media coverage?

plt.figure()
x_axis = media_Type
y_axis = PV
plt.bar(x_axis, y_axis)
plt.title('Content measured by publicity value')
plt.xlabel('Media Type')
plt.ylabel('Publicity Value')
plt.show()

#print(df.head())

# %%
#%%

# What content generates the greatest audience in media coverage?

plt.figure()
x_axis = media_Type
y_axis = audience
plt.bar(x_axis, y_axis)
plt.title('Content measured by Audience')
plt.xlabel('Media Type')
plt.ylabel('Audience')
plt.show()
